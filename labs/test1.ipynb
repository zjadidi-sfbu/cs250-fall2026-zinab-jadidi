# %% [markdown]
# <a href="https://colab.research.google.com/github/zjadidi-sfbu/cs250-fall2026-zinab-jadidi/blob/main/labs/test1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("welcome to cs250 -lab00")
# Out:
# welcome to cs250 -lab00
